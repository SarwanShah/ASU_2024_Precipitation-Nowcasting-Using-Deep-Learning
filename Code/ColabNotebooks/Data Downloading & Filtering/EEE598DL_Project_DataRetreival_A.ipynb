# %% [markdown]
# # Import Dependencies for Cloud Retrieval

# %%
# !wget -O azcopy.tar.gz https://aka.ms/downloadazcopy-v10-linux
# !tar -xvf azcopy.tar.gz
# !sudo cp ./azcopy_linux_amd64_10.27.1/azcopy /usr/bin/
from datetime import datetime
from dateutil.relativedelta import relativedelta
import os

from google.colab import drive
drive.mount('/content/drive')
# Out:
# --2024-11-21 10:46:41--  https://aka.ms/downloadazcopy-v10-linux
# Resolving aka.ms (aka.ms)... 184.85.109.247
# Connecting to aka.ms (aka.ms)|184.85.109.247|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://azcopyvnext.azureedge.net/releases/release-10.27.1-20241113/azcopy_linux_amd64_10.27.1.tar.gz [following]
# --2024-11-21 10:46:41--  https://azcopyvnext.azureedge.net/releases/release-10.27.1-20241113/azcopy_linux_amd64_10.27.1.tar.gz
# Resolving azcopyvnext.azureedge.net (azcopyvnext.azureedge.net)... 117.18.232.200, 2606:2800:147:120f:30c:1ba0:fc6:265a
# Connecting to azcopyvnext.azureedge.net (azcopyvnext.azureedge.net)|117.18.232.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23326759 (22M) [application/gzip]
# Saving to: ‘azcopy.tar.gz’
#
# azcopy.tar.gz       100%[===================>]  22.25M  23.5MB/s    in 0.9s
#
# 2024-11-21 10:46:43 (23.5 MB/s) - ‘azcopy.tar.gz’ saved [23326759/23326759]
#
# azcopy_linux_amd64_10.27.1/
# azcopy_linux_amd64_10.27.1/NOTICE.txt
# azcopy_linux_amd64_10.27.1/azcopy
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Downloading All Samples In A Specified Date Range

# %%
# Finding All Urls in Specified Date Range
years = ['2020']
start_date = datetime.strptime("07", "%m")
end_date = datetime.strptime("09", "%m")
for year in years:
    current_date = start_date
    while current_date <= end_date:
        smonth = current_date.strftime('%m')
        print(f'Downloading for {smonth}/{year}')
        source_url = f"https://ghe.blob.core.windows.net/noaa-ghe/rain_rate/{year}/{smonth}"
        destination_path = f"/content/ghe_data/{year}/{smonth}"
        # !mkdir -p "{destination_path}"
        # !azcopy copy "{source_url}" "{destination_path}" --recursive
        current_date += relativedelta(months=1)  # Increment by one month
# Out:
# Downloading for 07/2020
# INFO: Scanning...
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job d259cf4d-56d5-b645-6afd-89687d8b778c has started
# Log file is located at: /root/.azcopy/d259cf4d-56d5-b645-6afd-89687d8b778c.log
#
# 100.0 %, 2974 Done, 0 Failed, 0 Pending, 0 Skipped, 2974 Total,
#
#
# Job d259cf4d-56d5-b645-6afd-89687d8b778c summary
# Elapsed Time (Minutes): 1.735
# Number of File Transfers: 2974
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 2974
# Number of File Transfers Completed: 2974
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# Total Number of Bytes Transferred: 7264491444
# Final Job Status: Completed
#
# Downloading for 08/2020
# INFO: Scanning...
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 7c4b7e76-d7a3-6742-4c91-9ce7caad79e0 has started
# Log file is located at: /root/.azcopy/7c4b7e76-d7a3-6742-4c91-9ce7caad79e0.log
#
# 100.0 %, 2975 Done, 0 Failed, 0 Pending, 0 Skipped, 2975 Total,
#
#
# Job 7c4b7e76-d7a3-6742-4c91-9ce7caad79e0 summary
# Elapsed Time (Minutes): 1.8637
# Number of File Transfers: 2975
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 2975
# Number of File Transfers Completed: 2975
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# Total Number of Bytes Transferred: 7684183790
# Final Job Status: Completed
#
# Downloading for 09/2020
# INFO: Scanning...
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job e6c7bb02-4514-8d46-5964-8ad501921b1a has started
# Log file is located at: /root/.azcopy/e6c7bb02-4514-8d46-5964-8ad501921b1a.log
#
# 100.0 %, 2880 Done, 0 Failed, 0 Pending, 0 Skipped, 2880 Total,
#
#
# Job e6c7bb02-4514-8d46-5964-8ad501921b1a summary
# Elapsed Time (Minutes): 1.8364
# Number of File Transfers: 2880
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 2880
# Number of File Transfers Completed: 2880
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# Total Number of Bytes Transferred: 7483743683
# Final Job Status: Completed

# %%
# Define source and destination paths
source_path = "/content/ghe_data/2020"
destination_path = "/content/drive/My Drive/Graduate - Academic Work/Semester 3/EEE598 Deep Learning/Project Proposal/Data/Raw/2020"

# Create the destination directory if it doesn't exist
os.makedirs(destination_path, exist_ok=True)

# Move the folder
# !mv "{source_path}" "{destination_path}"
# Out:
# mv: cannot stat '/content/ghe_data/2020': No such file or directory
